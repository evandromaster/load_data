# %%
import numpy as np
import pandas as pd
import glob as gl

# %%
#path = r'C:\Users\Evandro\Jupyter\bigdata\files\'
path = r'C:\Users\Geo\Jupyter\load_data\files\'
#filenames = glob.glob(path + "/*.xls")
#print(filenames)
stock_files = sorted(gl.glob(r'C:\Users\Evandro\Jupyter\bigdata\files\*.xls'))
stock_files
# Out:
#   File "<ipython-input-1-0e56344758b4>", line 2
#     path = r'C:\Users\Geo\Jupyter\load_data\files\'
#                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
pd.concat((pd.read_excel(file, sheet_name='tbl_ocorrencias').assign(filename = file)
    for file in stock_files), ignore_index = True)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#               Número REDS Órgão Unidade Registro  \
# 0      2020-023145824-001        POLICIA MILITAR
# 1      2020-027659060-001        POLICIA MILITAR
# 2      2020-027530911-001        POLICIA MILITAR
# 3      2020-025911251-001        POLICIA MILITAR
# 4      2020-025895677-001        POLICIA MILITAR
# ...                   ...                    ...
# 21127  2020-030832421-001        POLICIA MILITAR
# 21128  2020-026482732-001        POLICIA MILITAR
# 21129  2020-030451331-001        POLICIA MILITAR
# 21130  2020-026704897-001        POLICIA MILITAR
# 21131  2020-028877965-001        POLICIA MILITAR
#
#                 Unidade Área Militar             Unidade Relato Nível 6  \
# 0      3 PEL/139 CIA PM/23 BPM/7 RPM      7 CIA PM MAMB/BPM MAMB/CPMAMB
# ...

# %%
pd.concat((pd.read_csv(file, delimiter = ';').assign(filename = file)
    for file in stock_files), ignore_index = True)
          
#df_crimes = pd.read_excel(dir_crimes, sheet_name='tbl_crimes')
# Out:
#            Número REDS Órgão Unidade Registro           Unidade Área Militar  \
# 0   2020-023145824-001        POLICIA MILITAR  3 PEL/139 CIA PM/23 BPM/7 RPM
# 1   2020-027659060-001        POLICIA MILITAR                       INVÁLIDO
# 2   2020-027530911-001        POLICIA MILITAR          50 CIA PM/7 BPM/7 RPM
# 3   2020-025911251-001        POLICIA MILITAR      3 PEL/19 CIA PM IND/7 RPM
# 4   2020-023145824-001        POLICIA MILITAR  3 PEL/139 CIA PM/23 BPM/7 RPM
# 5   2020-027659060-001        POLICIA MILITAR                       INVÁLIDO
# 6   2020-027530911-001        POLICIA MILITAR          50 CIA PM/7 BPM/7 RPM
# 7   2020-025911251-001        POLICIA MILITAR      3 PEL/19 CIA PM IND/7 RPM
# 8   2020-023145824-001        POLICIA MILITAR  3 PEL/139 CIA PM/23 BPM/7 RPM
# 9   2020-027659060-001        POLICIA MILITAR                       INVÁLIDO
# 10  2020-027530911-001        POLICIA MILITAR          50 CIA PM/7 BPM/7 RPM
# ...

# %%
print(df)
# Out:
# {'tbl_ocorrencias':              Número REDS Órgão Unidade Registro  \
# 0     2020-023145824-001        POLICIA MILITAR
# 1     2020-027659060-001        POLICIA MILITAR
# 2     2020-027530911-001        POLICIA MILITAR
# 3     2020-025911251-001        POLICIA MILITAR
# 4     2020-025895677-001        POLICIA MILITAR
# ...                  ...                    ...
# 7039  2020-030832421-001        POLICIA MILITAR
# 7040  2020-026482732-001        POLICIA MILITAR
# 7041  2020-030451331-001        POLICIA MILITAR
# 7042  2020-026704897-001        POLICIA MILITAR
# 7043  2020-028877965-001        POLICIA MILITAR
#
#                Unidade Área Militar             Unidade Relato Nível 6  \
# 0     3 PEL/139 CIA PM/23 BPM/7 RPM      7 CIA PM MAMB/BPM MAMB/CPMAMB
# 1                          INVÁLIDO  SOU-OLHO VIVO/19 CIA PM IND/7 RPM
# 2             50 CIA PM/7 BPM/7 RPM              50 CIA PM/7 BPM/7 RPM
# 3         3 PEL/19 CIA PM IND/7 RPM                19 CIA PM IND/7 RPM
# ...
