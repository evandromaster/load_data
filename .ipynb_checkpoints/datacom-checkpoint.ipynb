# %%
# Importar bibliotecas
import os, time
import pandas as pd
import glob

# %%
# Mudando o diretorio
#os.chdir(r"C:\Users\Geo\Documents\MEGAsync\MySql\10 - Tbl_dimensao\pdca\files") #office
os.chdir(r"I:\MySql\10 - Tbl_dimensao\pdca\files") #Home
# Create a list with all the files
path = os.getcwd()
files = os.listdir(path)

# Selecionando  apenas os arquivos xls
files_xls = [f for f in files if f[-3:] == "xls"]

files_xls
# Out:
# ['tbl_base_pdca_2020_01.xls',
#  'tbl_base_pdca_2020_02.xls',
#  'tbl_base_pdca_2020_03.xls',
#  'tbl_base_pdca_2020_04.xls',
#  'tbl_base_pdca_2020_05.xls',
#  'tbl_base_pdca_2020_06.xls',
#  'tbl_base_pdca_2020_07.xls',
#  'tbl_base_pdca_2020_08.xls',
#  'tbl_base_pdca_2020_09.xls']

# %%
#initilizing the DataFrame empyt
df_files = pd.DataFrame()


for f in files_xls:
    dba = pd.read_excel(f, sheet_name='tbl_ocorrencias', index_col = None)
    df_files = df_files.append(dba)
#   df_files.columns = [c.replace(' ', '_') for c in df_files.columns]
#   df_files.columns = [c.upper() for c in df_files.columns]
#   col_names = df_files.columns
df_files.columns = df_files.columns.str.replace(' ', '_')
df_files.columns = df_files.columns.str.upper()
df_files.set_index("NÚMERO_REDS", inplace = True)

df_files
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (10597214) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (9995841) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (8596052) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (9769808) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (9423183) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (9739285) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (9534378) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#                    ÓRGÃO_UNIDADE_REGISTRO           UNIDADE_ÁREA_MILITAR  \
# NÚMERO_REDS
# 2019-064031928-001          POLICIA CIVIL        280 CIA PM/60 BPM/7 RPM
# 2020-001344784-001          POLICIA CIVIL  3 PEL/139 CIA PM/23 BPM/7 RPM
# 2020-001165172-001          POLICIA CIVIL                    7 BPM/7 RPM
# 2016-010557222-002          POLICIA CIVIL   1 PEL/118 CIA PM/7 BPM/7 RPM
# 2019-060941947-001          POLICIA CIVIL  2 PEL/241 CIA PM/63 BPM/7 RPM
# ...                                   ...                            ...
# 2020-043061660-001        POLICIA MILITAR  3 PEL/241 CIA PM/63 BPM/7 RPM
# 2020-043122958-001        POLICIA MILITAR  3 PEL/241 CIA PM/63 BPM/7 RPM
# 2020-043034880-001        POLICIA MILITAR  3 PEL/241 CIA PM/63 BPM/7 RPM
# 2020-042156670-001        POLICIA MILITAR  3 PEL/241 CIA PM/63 BPM/7 RPM
# 2020-043605348-001        POLICIA MILITAR  3 PEL/241 CIA PM/63 BPM/7 RPM
#
#                                               UNIDADE_RELATO_NÍVEL_6  \
# NÚMERO_REDS
# 2019-064031928-001                                     NAO INFORMADO
# 2020-001344784-001             5ª DELEGACIA DE POLICIA CIVIL/CLAUDIO
# 2020-001165172-001  2ª DELEGACIA REGIONAL POLICIA CIVIL/BOM DESPACHO
# 2020-001344784-001                       CONSUMADO                   7777777
# 2020-001165172-001                       CONSUMADO                   7777777
# 2016-010557222-002                       CONSUMADO                    B01147
# 2019-060941947-001                       CONSUMADO                   7777777
# ...                                            ...                       ...
# 2020-043061660-001                       CONSUMADO                   7777777
# 2020-043122958-001                       CONSUMADO                    G01329
# 2020-043034880-001                       CONSUMADO                   7777777
# 2020-042156670-001                       CONSUMADO                   7777777
# 2020-043605348-001                       CONSUMADO                   7777777
#
#                    TENTADO/CONSUMADO_NAT_SEC1 CÓDIGO_SUBCLASSE_NAT_SEC2  ...  \
# NÚMERO_REDS                                                              ...
# 2019-064031928-001     PREENCHIMENTO OPCIONAL                   7777777  ...
# 2020-001344784-001     PREENCHIMENTO OPCIONAL                   7777777  ...
# 2020-001165172-001     PREENCHIMENTO OPCIONAL                   7777777  ...
# 2016-010557222-002                  CONSUMADO                    C01163  ...
# 2019-060941947-001     PREENCHIMENTO OPCIONAL                   7777777  ...
# ...                                       ...                       ...  ...
# 2020-043061660-001     PREENCHIMENTO OPCIONAL                   7777777  ...
# 2020-043122958-001                  CONSUMADO                    G01331  ...
# 2020-043034880-001     PREENCHIMENTO OPCIONAL                   7777777  ...
# 2020-042156670-001     PREENCHIMENTO OPCIONAL                   7777777  ...
# 2020-043605348-001     PREENCHIMENTO OPCIONAL                   7777777  ...
#
#                     LONGITUDE MATRÍCULA_DIGITADOR  \
# NÚMERO_REDS
# 2019-064031928-001        NaN         03172613631
# 2020-001344784-001        NaN           PC1189095
# 2020-001165172-001        NaN           PC1400431
# 2016-010557222-002        NaN           PC1113244
# 2019-060941947-001        NaN         07824584674
# ...                       ...                 ...
# 2020-043061660-001 -46.224973           PM1276864
# 2020-043122958-001 -46.225000           PM1156926
# 2020-043034880-001 -46.225606           PM1276864
# 2020-042156670-001 -46.226413           PM1734672
# 2020-043605348-001 -46.245071           PM1213040
#
#                                         CARGO_RELATOR  \
# NÚMERO_REDS
# 2019-064031928-001   INVESTIGADOR DE POLICIA NIVEL II
# 2020-001344784-001    ESCRIVAO DE POLICIA II NIVEL II
# 2020-001165172-001  INVESTIGADOR DE POLICIA I NIVEL I
# 2016-010557222-002   INVESTIGADOR POLICIA II NIVEL II
# 2019-060941947-001  INVESTIGADOR DE POLICIA I NIVEL I
# ...                                               ...
# 2020-043061660-001                         3 SARGENTO
# 2020-043122958-001                SOLDADO DE 1 CLASSE
# 2020-043034880-001                         3 SARGENTO
# 2020-042156670-001                SOLDADO DE 1 CLASSE
# 2020-043605348-001                         3 SARGENTO
#
#                                          NOME_RELATOR MATRÍCULA_RELATOR  \
# NÚMERO_REDS
# 2019-064031928-001        DANIEL FRANCISCO DAS CHAGAS           1256984
# 2020-001344784-001        EUCLIDES GONCALVES DA CUNHA           1189095
# 2020-001165172-001  ROBERTA HELAINE SILVA TELES COSTA           1400431
# 2016-010557222-002          PINDARO GONCALVES BARBOSA           1113244
# 2019-060941947-001            DONATO DAVID DOS SANTOS           1412994
# ...                                               ...               ...
# 2020-043061660-001                      LELIO MOREIRA           1276864
# 2020-043122958-001        KAIO CESAR DE SOUZA FONSECA           1684935
# 2020-043034880-001                      LELIO MOREIRA           1276864
# 2020-042156670-001         ANDERSON GONCALVES RIBEIRO           1734672
# 2020-043605348-001          EDIR EVANGELISTA DA SILVA           1213040
#
#                               TIPO_VIATURA NÚMERO_REGISTRO_VIATURA  \
# NÚMERO_REDS
# 2019-064031928-001  PREENCHIMENTO OPCIONAL               7777777.0
# 2020-001344784-001  PREENCHIMENTO OPCIONAL               7777777.0
# 2020-001165172-001  PREENCHIMENTO OPCIONAL               7777777.0
# 2016-010557222-002  PREENCHIMENTO OPCIONAL               7777777.0
# 2019-060941947-001  PREENCHIMENTO OPCIONAL               7777777.0
# ...                                    ...                     ...
# 2020-043061660-001      VIATURA COM CELA -                 28080.0
# 2020-043122958-001      VIATURA COM CELA -                 28080.0
# 2020-043034880-001      VIATURA COM CELA -                 28080.0
# 2020-042156670-001      VIATURA COM CELA -                 28080.0
# 2020-043605348-001             CAMIONETA -                 20007.0
#
#                    QTDE_OCORRÊNCIAS TEMPO_MÉDIO_ATENDIMENTO  \
# NÚMERO_REDS
# 2019-064031928-001                1                    34.0
# 2020-001344784-001                1                    18.0
# 2020-001165172-001                1                    19.0
# 2016-010557222-002                1                    19.0
# 2019-060941947-001                1                    39.0
# ...                             ...                     ...
# 2020-043061660-001                1                    33.0
# 2020-043122958-001                1                    79.0
# 2020-043034880-001                1                    50.0
# 2020-042156670-001                1                    37.0
# 2020-043605348-001                1                   340.0
#
#                    TEMPO_MÉDIO_PREENCHIMENTO
# NÚMERO_REDS
# 2019-064031928-001              21474.983333
# 2020-001344784-001               1472.033333
# 2020-001165172-001                 19.583333
# 2016-010557222-002                 12.500000
# 2019-060941947-001              40020.050000
# ...                                      ...
# 2020-043061660-001               1500.033333
# 2020-043122958-001                177.966667
# 2020-043034880-001               1508.033333
# 2020-042156670-001                684.483333
# 2020-043605348-001               1731.033333
#
# [84937 rows x 44 columns]

# %%
df_files['DATA_COMUNICAÇÃO_FATO']

df_files['DATA_COMUNICAÇÃO_FATO'] = pd.to_datetime(df_files['DATA_COMUNICAÇÃO_FATO'], format='%Y/%m/%d', errors='coerce')

#df_files['DATA_COMUNICAÇÃO_FATO'] = df_files['DATA_COMUNICAÇÃO_FATO'].astype(str)

# %%
df_files['DATA_COMUNICAÇÃO_FATO'].filter(regex ='[9999]')


# select rows containing 'ion'
df = df_files['DATA_COMUNICAÇÃO_FATO'].filter(like='9999', axis=0)

# %%
save = r"C:\Users\Evandro\Desktop\tbl_.xlsx"
df.to_excel(save, sheet_name='validados', index = False)

# %%
df_files.columns

# %%
####selecionnado apenas 9999
df_files[df_files['DATA_COMUNICAÇÃO_FATO'].astype(str).str[:4] == '9999']['DATA_COMUNICAÇÃO_FATO']

#df_files['DATA_COMUNICAÇÃO_FATO'] = df_files['DATA_COMUNICAÇÃO_FATO'].astype(str).str.replace('9999', df_files['DATA_INC'])

# %%
####selecionnado apenas 9999
df_files['DATA_9999'] = df_files[df_files['DATA_COMUNICAÇÃO_FATO'].astype(str).str[:4] == '9999']['DATA_COMUNICAÇÃO_FATO']

df_files['DATA_INC'] = df_files['DATA_HORA_INCLUSÃO_REDS'].dt.strftime('%Y-%m-%d')




df_files['DATA_COMUNICAÇÃO_FATO'] = df_files['DATA_COMUNICAÇÃO_FATO'].apply(lambda x: df_files['DATA_INC'] if x == df_files['DATA_9999'] else df_files['DATA_COMUNICAÇÃO_FATO'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-91ad469c0fce> in <module>
#       7
#       8
# ----> 9 df_files['DATA_COMUNICAÇÃO_FATO'].apply(lambda x: df_files['DATA_INC'] if x == df_files['DATA_9999'] else df_files['DATA_COMUNICAÇÃO_FATO'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-16-91ad469c0fce> in <lambda>(x)
#       7
#       8
# ----> 9 df_files['DATA_COMUNICAÇÃO_FATO'].apply(lambda x: df_files['DATA_INC'] if x == df_files['DATA_9999'] else df_files['DATA_COMUNICAÇÃO_FATO'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df_files[df_files['DATA_COMUNICAÇÃO_FATO'].astype(str).str[:4] == '2333']['DATA_COMUNICAÇÃO_FATO']
#df_files['DATA_COMUNICAÇÃO_FATO'].astype(str)

# %%
df_files[df_files['DATA_COMUNICAÇÃO_FATO'].str[:4] == '2333']['DATA_COMUNICAÇÃO_FATO']

# %%
df_files.to_sql('tbl_ocorrencias', 'sqlite:///armazem.db', if_exists='replace', index=True)
df_tbl_imported.to_sql('tbl_imported_files', 'sqlite:///armazem.db', if_exists='replace', index=False)

# %%
def get_files_names(only_not_imported=True):
    if only_not_imported:
            df_imported_files = pd.read_sql_table('tbl_imported_files', 'sqlite:///armazem.db')
            files_names = [files_xls for files_xls in files_names if files_xls not in df_imported_files['0'].values ]

# %%
import sqlite3
import pandas as pd
# Create your connection.
cnx = sqlite3.connect('armazem.db')

pd.read_sql_query("SELECT * FROM tbl_ocorrencias\
                   WHERE CÓDIGO_SUBCLASSE_NAT_PRINCIPAL = 'C01157'\
                   AND DATA_FATO > '2020-09-01'\
                    ", cnx)

# %%
pd.read_sql_query("SELECT count(*) FROM tbl_ocorrencias\
                   WHERE CÓDIGO_SUBCLASSE_NAT_PRINCIPAL = 'C01157'\
                   AND DATA_FATO > '2020-09-01'\
                    ", cnx)
